# %%
from component import io
from sepal_ui import aoi 

aoi_io = aoi.Aoi_io(default_asset = 'users/bornToBeAlive/aoi_sandan') #small 2 administrative level of Cambodgia
io = io.FcdmIo() 
# basemap 
io.forest_map = 'gfc'
io.forest_map_year = 2018
io.treecover = 70

# sensors 
io.index = 'ndvi'
io.sensor = 'landsat 8'
io.cloud_buffer = 500
io.landsat_7_threshold = 0.08
io.landsat_7_is_threshold = False

# time 
io.analysis_start = '2019-01-01'
io.analysis_end = '2019-12-31'
io.reference_start = '2018-01-01'
io.reference_end = '2018-12-31'

# fcdm 
io.kernel_radius = 150
io.filter_threshod = 0.035
io.filter_radius = 80
io.cleaning_offset = 3
io.__dict__

# %%
from sepal_ui import mapping as sm

Map = sm.SepalMap()
Map
