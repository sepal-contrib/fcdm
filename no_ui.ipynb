# %%
# !!! testing purpose !!!
#import os
#os.environ["CUSTOM_LANGUAGE"] = "fr"

# %%
# load the patial files
# %run 'aoi_ui.ipynb'
# %run 'about_ui.ipynb'
# %run 'fcdm_process_ui.ipynb'

# %%
# display each tile individually

# %%
aoi_tile

# %%
process_tile

# %%
result_tile

# %%
fcdm_model.__dict__

# %%
result_tile.m.zoom

# %%
result_tile.m.max_zoom
